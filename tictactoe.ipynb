# %%
# import os


# def clear_output():
#     os.system("cls")
from IPython.display import clear_output


def check_winning_condition(mark, n_list):
    if (
        (n_list[1] == mark and n_list[2] == mark and n_list[3] == mark)
        or (n_list[4] == mark and n_list[5] == mark and n_list[6] == mark)
        or (n_list[7] == mark and n_list[8] == mark and n_list[9] == mark)
        or (n_list[1] == mark and n_list[4] == mark and n_list[7] == mark)
        or (n_list[1] == mark and n_list[5] == mark and n_list[9] == mark)
        or (n_list[2] == mark and n_list[5] == mark and n_list[8] == mark)
        or (n_list[3] == mark and n_list[6] == mark and n_list[9] == mark)
        or (n_list[3] == mark and n_list[5] == mark and n_list[7] == mark)
    ):
        return True
    else:
        return False


def display(n_list):
    clear_output()
    print("-" * 17)
    print("{:^5}|{:^5}|{:^5}".format(n_list[7], n_list[8], n_list[9]))
    print("-" * 17)
    print("{:^5}|{:^5}|{:^5}".format(n_list[4], n_list[5], n_list[6]))
    print("-" * 17)
    print("{:^5}|{:^5}|{:^5}".format(n_list[1], n_list[2], n_list[3]))
    print("-" * 17)

    # n_list = {}


n_list = {9: "", 8: "", 7: "", 6: "", 5: "", 4: "", 3: "", 2: "", 1: ""}
display(n_list)
game = True
i = 0
status = 0
while game == True:
    i = 0
    status = 0
    n_list = {9: "", 8: "", 7: "", 6: "", 5: "", 4: "", 3: "", 2: "", 1: ""}
    while i < 10:
        if i % 2 == 0:
            temp = int(input("Player One : "))
            if n_list[temp] == "":
                n_list[temp] = "X"
                i += 1
                display(n_list)
            else:
                print("Cant Overide")
            #         display(n_list)
            if check_winning_condition("X", n_list):
                print("PLayer One Won")
                status = 1
                break
        else:
            temp = int(input("Player Two : "))
            if n_list[temp] == "":
                n_list[temp] = "O"
                i += 1
                display(n_list)
            else:
                print("Cant Overide")
            #         display(n_list)
            if check_winning_condition("O", n_list):
                print("Player Two Won")
                status = 1
                break
    if status == 0:
        print("Its a Draw")
    ch = int(input("Play Again\n1 - YES\n2 - NO\n\n"))
    if ch == 2:
        game = False
        print("Exiting")
# Out:
# -----------------
#      |     |
# -----------------
#      |     |
# -----------------
#      |     |
# -----------------
# Player One : 1
# -----------------
#      |     |
# -----------------
#      |     |
# -----------------
#   X  |     |
# -----------------
# Player Two : 3
# -----------------
#      |     |
# -----------------
#      |     |
# -----------------
#   X  |     |  O
# -----------------
# Player One :
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [1], in <cell line: 42>()
#      46 while i < 10:
#      47     if i % 2 == 0:
# ---> 48         temp = int(input("Player One : "))
#      49         if n_list[temp] == "":
#      50             n_list[temp] = "X"
#
# ValueError: invalid literal for int() with base 10: ''
